# %% [markdown]
# # Financial Data Analysis

# %% [markdown]
# First we have to import required libraries for the data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the data set and Explore the data

# %%
data=pd.read_excel(r"C:\Users\ano_k\Entri class\Financial Sample (1).xlsx")
data
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4   Units Sold             700 non-null    float64
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
# ...

# %%
data.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold  \
# 0  Government   Canada   Carretera            None       1618.5
# 1  Government  Germany   Carretera            None       1321.0
# 2   Midmarket   France   Carretera            None       2178.0
# 3   Midmarket  Germany   Carretera            None        888.0
# 4   Midmarket   Mexico   Carretera            None       2470.0
#
#    Manufacturing Price   Sale Price    Gross Sales   Discounts   \
# 0               $ 3.00      $ 20.00    $ 32,370.00       $ -
# 1               $ 3.00      $ 20.00    $ 26,420.00       $ -
# 2               $ 3.00      $ 15.00    $ 32,670.00       $ -
# 3               $ 3.00      $ 15.00    $ 13,320.00       $ -
# 4               $ 3.00      $ 15.00    $ 37,050.00       $ -
#
#           Sales           COGS         Profit       Date  Month Number  \
# 0   $ 32,370.00    $ 16,185.00    $ 16,185.00   1/1/2014             1
# ...

# %%
data.tail()
# Out:
#               Segment                   Country    Product   Discount Band   \
# 695    Small Business                    France   Amarilla            High
# 696    Small Business                    Mexico   Amarilla            High
# 697        Government                    Mexico    Montana            High
# 698        Government                    Canada      Paseo            High
# 699  Channel Partners  United States of America        VTT            High
#
#      Units Sold  Manufacturing Price   Sale Price     Gross Sales   \
# 695      2475.0             $ 260.00     $ 300.00    $ 742,500.00
# 696       546.0             $ 260.00     $ 300.00    $ 163,800.00
# 697      1368.0               $ 5.00       $ 7.00      $ 9,576.00
# 698       723.0              $ 10.00       $ 7.00      $ 5,061.00
# 699      1806.0             $ 250.00      $ 12.00     $ 21,672.00
#
#          Discounts           Sales            COGS         Profit        Date  \
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# data=data.fillna(value={'Discount Band':"No Discount"})
# data

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[["Units Sold","Manufacturing Price","Sale Price","Gross Sales","Discounts"," Sales","COGS","Profit"]].describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   700.000000           700.000000  700.000000  7.000000e+02
# mean   1608.294286            96.477143  118.428571  1.827594e+05
# std     867.427859           108.602612  136.775515  2.542623e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     905.000000             5.000000   12.000000  1.739175e+04
# 50%    1542.500000            10.000000   20.000000  3.798000e+04
# 75%    2229.125000           250.000000  300.000000  2.790250e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
#
#            Discounts         Sales           COGS         Profit
# count     700.000000  7.000000e+02     700.000000     700.000000
# mean    13150.354629  1.696091e+05  145475.211429   24133.860371
# std     22962.928775  2.367263e+05  203865.506118   42760.626563
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# ...

# %%
net_profit = data['Profit'].sum()
print("Net Profit:", net_profit)
total_sales=data[" Sales"].sum()
print(" Total Sales= ",total_sales)
total_discounts=data["Discounts"].sum()
print("Total Discounts",total_discounts)
# Out:
# Net Profit: 16893702.259999998
#  Total Sales=  118726350.25999999
# Total Discounts 9205248.24

# %% [markdown]
# #  Visualization

# %%
#product wise profit
fig=plt.figure(figsize=(10,5))
data1=data.groupby("Product")["Profit"].sum().sort_values(ascending=False)
plt.bar(data1.index,data1,color="g",edgecolor="black",width=0.7)
plt.xlabel("Product")
plt.ylabel("Net profit")
plt.title("Product Vs Profit")
plt.show()

# %% [markdown]
# From the above analysis paseo is the most profitable product and carretera is the least profitable product.

# %%
figure = plt.figure(figsize =(10, 3))
data2=data.groupby("Segment")["Profit"].sum().sort_values(ascending=False)
plt.bar(df.index,df,color="b",edgecolor="black",width=0.5)
plt.xlabel('Segment')
plt.ylabel('Net Profit')
plt.show()

# %% [markdown]
# Government segent have highest profit, Enterprise have least profitable segment.

# %%
#Country wise sales analysis
df=data.groupby("Country")[" Sales"].sum()
fig, ax = plt.subplots()
ax.pie(df,labels=df.index,shadow="True",autopct='%1.1f%%')
plt.legend(title = "Country",bbox_to_anchor=(1.2, 1.2),loc='upper left',shadow="True")
center_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(center_circle)
ax.axis('equal')
plt.title('Country-wise Sales')
plt.show()

# %% [markdown]
# USA is the country with more sales and mexico is the lowest sales.

# %%
df=data.groupby("Country")["Profit"].sum()
fig, ax = plt.subplots()
ax.pie(df,labels=df.index,shadow="True",autopct='%1.1f%%')
plt.legend(title = "Country",bbox_to_anchor=(1.2, 1.2),loc='upper left',shadow="True")
center_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(center_circle)
ax.axis('equal')
plt.title('Country-wise Profit')
plt.show()

# %% [markdown]
# Based on the profit wise analysis france having the most profit. Both sales wise and profit wise analysis Mexico getting least position.

# %%
figure = plt.figure(figsize =(10, 3))
df=data.groupby("Discount Band")["Units Sold"].sum().sort_values(ascending=False)
plt.bar(df.index,df,color="r",edgecolor="black",width=0.5)
plt.xlabel('Discount Band')
plt.ylabel('Units Sold')
plt.title("Discount Band Vs Units Sold")
plt.show()

# %%
figure = plt.figure(figsize =(10, 3))
df=data.groupby("Discount Band")[" Sales"].sum().sort_values(ascending=False)
plt.bar(df.index,df,color='b',edgecolor="black",width=0.5)
plt.xlabel('Discount Band')
plt.ylabel('Net Sales')
plt.title("Discount band Vs Net sales")
plt.show()

# %%
figure = plt.figure(figsize =(10, 3))
df=data.groupby("Discount Band")["Profit"].sum().sort_values(ascending=False)
plt.bar(df.index,df,color="y",edgecolor="black",width=0.5)
plt.xlabel('Discount Band')
plt.ylabel('Net Profit')
plt.title("Discount band Vs net profit")
plt.show()

# %%
total_loss = data[data['Profit'] < 0]['Profit'].sum()
print("Total Loss:", total_loss,"K")
# Out:
# Total Loss: -777321.25 K
